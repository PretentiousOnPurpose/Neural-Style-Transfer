# %%
import tensorflow as tf
from keras.applications import VGG16
from PIL import Image
import numpy as np
import keras.backend as K
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
height = 300; width = 400

# %%
c = np.array(Image.open("c.jpg").resize((width, height))).reshape(1, height, width, 3)
s = np.array(Image.open("s.jpg").resize((width, height))).reshape(1, height, width, 3)

# %%
plt.imshow(c[0])

# %%
plt.imshow(s[0])

# %%
c = c[:, :, :, ::-1]
s = s[:, :, :, ::-1]

# %%
# C = tf.Variable(value = c, dtype = tf.float32)
# S = tf.Variable(value = s, dtype = tf.float32)
C = tf.Variable(initial_value= c, dtype = tf.float32)
S = tf.Variable(initial_value= s, dtype= tf.float32)

W = tf.Variable(initial_value= tf.random_normal(shape = (1, height, width, 3)))

# %%
Inp = tf.concat(values = [C, S, W], axis = 0)
# Inp = tf.placeholder(dtype = tf.float32, shape = (3, height, width, 3))

# %%
model = VGG16(include_top=False, input_tensor= Inp)

# %%
[layer.name for layer in model.layers]
# Out:
# ['input_1',
#  'block1_conv1',
#  'block1_conv2',
#  'block1_pool',
#  'block2_conv1',
#  'block2_conv2',
#  'block2_pool',
#  'block3_conv1',
#  'block3_conv2',
#  'block3_conv3',
#  'block3_pool',
#  'block4_conv1',
#  'block4_conv2',
#  'block4_conv3',
#  'block4_pool',
#  'block5_conv1',
#  'block5_conv2',
#  'block5_conv3',
#  'block5_pool']

# %%
Loss = 0.0

# %%
# content_samples = ['block4_conv1']

# %%
def content_loss():
    Out = model.get_layer(index = 11).output
    return tf.reduce_mean(tf.square(Out[0] - Out[2]))/(4 * height * width * 3)

# %%
Loss += content_loss()

# %%
# This function is taken from fchollet's implementation
def gram_matrix(x):
    features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    gram = K.dot(features, K.transpose(features))
    return gram

# %%
def style_loss():
    Out1 = model.get_layer(index = 13).output
    Out2 = model.get_layer(index = 15).output
    Out3 = model.get_layer(index = 17).output
    Out = [Out1, Out2, Out3]
    style = 0.0
    for i in range(3):
        style += tf.reduce_mean(tf.square(gram_matrix(Out[i][1]) - gram_matrix(Out[i][2])))/((3 * height * width)**2)
    
    return style

# %%
Loss += style_loss()

# %%
grads = K.gradients(Loss, W)

# %%
opt = tf.train.AdamOptimizer(learning_rate = 0.005)

# %%
sess = tf.InteractiveSession()

# %%
sess.run(tf.global_variables_initializer())

# %%
def train(w, lr = 0.001, epochs = 1):
    X = np.random.normal(0, 1, size = (1, height, width, 3)).astype(np.float32)
#     Con_X = np.concatenate((C, S, W), axis = 0)
#     Con_X = tf.convert_to_tensor(value = Con_X, dtype = np.float32)
    for e in range(epochs):
        grad, loss = sess.run([grads, Loss], feed_dict={W:X})
        K.update_sub(w, (lr * tf.convert_to_tensor(grad[0])))
    return sess.run(W)[0]

# %%
img = train(W)

# %%
img = sess.run(img)

# %%
plt.imshow(img[0])
